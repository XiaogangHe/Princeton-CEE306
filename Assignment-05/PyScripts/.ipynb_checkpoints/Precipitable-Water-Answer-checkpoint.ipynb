# %% [markdown]
# The `%matplotlib` magic command is used here to enable plotting in the current notebook. The `inline` backend will embed plots inside the notebook.

# %%
# %matplotlib inline

# %% [markdown]
# #### Import necessary modules

# %%
import os
import numpy as np
import pandas as pd
import glob
import matplotlib.pyplot as plt

# %% [markdown]
# #### Create a file list for the yearly files

# %%
file_paths = []
ID = 'AZPG*'
for root, dirs, files in os.walk('../Data/'): 
       file_paths += glob.glob(os.path.join(root, ID))

# %% [markdown]
# #### Read each file and append to previous year

# %%
dff = []
for file_path in file_paths:
         df = pd.read_csv(file_path, delim_whitespace = True,  usecols=[0,1,4,5,6], header = None)
         df.columns = ["decday", "pwv",  "P", "T", "RH"]
         lhs, rhs =  file_path.split("_")
         yyy, junk = rhs.split(".")
         yy2 = str(int(yyy)-1)
         prevyear =  yy2 + str('-12-31')
         df['date'] = pd.Timestamp(prevyear)
         df['date'] = df['date'] + pd.to_timedelta(df['decday'], unit ='D')
         dff.append(df)
dff = pd.concat(dff, axis=0)
dff['datetime'] = pd.to_datetime(dff['date'])
dff['month'] = dff['datetime'].dt.month
dff = dff.set_index('datetime')
dff = dff[dff['pwv'] > 0]    # Select valid values

# %% [markdown]
# #### We can make a scatter plot to investigate the relationship between temperature and precipitable water

# %%
dff.plot(kind='scatter', x='T', y='pwv')
plt.xlabel('Temperature, C')
plt.ylabel('PWV, mm');

# %%
dff.plot.hexbin(x='T', y='pwv')
plt.xlabel('Temperature, C')
plt.ylabel('PWV, mm');

# %% [markdown]
# Calculate the specific humidity and make the scatter plot:

# %%
def specific_humidity(T, RH):
    es = 611*np.exp(17.27*T/(237.3+T))
    e = RH*es
    sh = 0.622*e/100000
    
    return sh

# %%
SH = specific_humidity(dff['T'], dff['RH']/100)
dff['SH'] = SH

# %%
dff.plot(kind='scatter', x='SH', y='pwv')
plt.xlabel('Specific humidity')
plt.ylabel('PWV, mm');

# %% [markdown]
# #### We can make boxplots of precipitable water by season

# %%
dff.boxplot('pwv', by=dff.month, whis=[10,90], sym=' ')
plt.xlabel('Month')
plt.ylabel('PWV, mm')
plt.title('Suomi Network, AZPG')
plt.suptitle("")
fname='../Figures/PWV_seasonal.pdf'
plt.savefig(fname)

# %% [markdown]
# #### Time series plot

# %%
dff.plot(y='pwv', style='.', label='PWV (mm)')
plt.legend(loc='best')
plt.ylabel('PWV, mm')
plt.ylim(ymax=40, ymin =0)
plt.title('Suomi Network, AZPG');

# %% [markdown]
# #### Change time axis range

# %%
dff2 = (dff.loc['2014-6-16':'2014-6-30'])
dff2.plot(y='pwv',style='.', label='PWV (mm)')
plt.legend(loc='best')
plt.ylabel('PWV, mm')
plt.ylim(ymax=40, ymin =0)
plt.title('Suomi Network, AZPG');

# %% [markdown]
# #### Show the statistics

# %%
dff.describe(percentiles = [.1,.25,.5])
# Out:
#              decday           pwv             P             T            RH  \
# count  37411.000000  37411.000000  37411.000000  37411.000000  37411.000000
# mean     205.309484     12.422803    868.188070     17.181845     36.439467
# std      101.559145      7.763853      4.930508     10.665422     21.556254
# min        1.385420      0.400000    848.900000    -10.000000      2.200000
# 10%       60.885420      4.300000    862.000000      2.200000     12.100000
# 25%      124.208335      6.500000    865.300000      8.000000     19.400000
# 50%      214.322920     10.100000    868.200000     18.000000     31.600000
# max      366.989580     40.500000    885.000000     41.000000    100.000000
#
#               month            SH
# count  37411.000000  37411.000000
# mean       7.239823      0.004166
# std        3.316288      0.002398
# min        1.000000      0.000507
# 10%        3.000000      0.001656
# 25%        5.000000      0.002258
# 50%        8.000000      0.003534
# max       12.000000      0.014546

# %%
dff.T
# Out:
# datetime 2012-06-15 00:15:00.288000000 2012-06-15 00:45:00.000000000  \
# decday                          167.01                       167.031
# pwv                                6.5                           6.2
# P                                860.3                         860.3
# T                                   35                            35
# RH                                   4                             4
# date        2012-06-15 00:15:00.288000           2012-06-15 00:45:00
# month                                6                             6
# SH                          0.00139938                    0.00139938
#
# datetime 2012-06-15 01:14:59.712000000 2012-06-15 01:45:00.288000000  \
# decday                         167.052                       167.073
# pwv                                  7                           7.3
# P                                860.3                         860.3
# T                                 34.4                            34
# RH                                 4.2                           4.2
# date        2012-06-15 01:14:59.712000    2012-06-15 01:45:00.288000
# month                                6                             6
# SH                          0.00142132                    0.00139006
#
# datetime 2012-06-15 02:15:00.000000000 2012-06-15 02:44:59.712000000  \
# decday                         167.094                       167.115
# pwv                                6.3                           6.5
# P                                860.5                         860.6
# T                                 32.8                            32
# RH                                 4.8                           5.1
# date               2012-06-15 02:15:00    2012-06-15 02:44:59.712000
# month                                6                             6
# SH                          0.00148552                     0.0015088
#
# datetime 2012-06-15 03:15:00.288000000 2012-06-15 03:45:00.000000000  \
# decday                         167.135                       167.156
# pwv                                6.8                           6.8
# P                                860.6                         860.6
# T                                 30.8                            30
# RH                                 5.3                           5.3
# date        2012-06-15 03:15:00.288000           2012-06-15 03:45:00
# month                                6                             6
# SH                          0.00146473                    0.00139923
#
# datetime  2012-06-15 04:14:59.711999999 2012-06-15 04:45:00.288000000  \
# decday                          167.177                       167.198
# pwv                                   7                           6.7
# P                                   861                         861.2
# T                                  28.8                            28
# RH                                    6                           6.5
# date      2012-06-15 04:14:59.711999999    2012-06-15 04:45:00.288000
# month                                 6                             6
# SH                           0.00147821                    0.00152873
#
# datetime              ...              2016-05-24 10:14:59.712000000  \
# decday                ...                                    145.427
# pwv                   ...                                        8.2
# P                     ...                                      861.4
# T                     ...                                       16.6
# RH                    ...                                       21.7
# date                  ...                 2016-05-24 10:14:59.712000
# month                 ...                                          5
# SH                    ...                                  0.0025507
#
# datetime 2016-05-24 10:45:00.288000000 2016-05-24 11:15:00.000000000  \
# decday                         145.448                       145.469
# pwv                                8.2                           8.5
# P                                861.4                         861.6
# T                                   17                          16.4
# RH                                21.8                          22.7
# date        2016-05-24 10:45:00.288000           2016-05-24 11:15:00
# month                                5                             5
# SH                          0.00262834                    0.00263451
#
# datetime 2016-05-24 11:44:59.712000000 2016-05-24 12:15:00.288000000  \
# decday                          145.49                        145.51
# pwv                                8.7                           8.9
# P                                861.7                         861.9
# T                                   16                          16.6
# RH                                23.2                          21.4
# date        2016-05-24 11:44:59.712000    2016-05-24 12:15:00.288000
# month                                5                             5
# SH                          0.00262472                    0.00251544
#
# datetime 2016-05-24 12:45:00.000000000 2016-05-24 13:14:59.712000000  \
# decday                         145.531                       145.552
# pwv                                8.8                           9.2
# P                                  862                         862.2
# T                                   17                            17
# RH                                20.2                          21.2
# date               2016-05-24 12:45:00    2016-05-24 13:14:59.712000
# month                                5                             5
# SH                          0.00243544                      0.002556
#
# datetime 2016-05-24 13:45:00.288000000 2016-05-24 14:15:00.000000000  \
# decday                         145.573                       145.594
